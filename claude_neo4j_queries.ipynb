# %%
from anthropic import Anthropic
import pandas as pd
import neo4j
from neo4j import GraphDatabase
from IPython.display import display

# %%
client = Anthropic()
MODEL_NAME = "claude-3-opus-20240229"

# %%
driver = GraphDatabase.driver("neo4j://localhost:7687", auth=("neo4j", "neo4j"))

# %%
def to_dataframe(query, driver, database):
    records, summary, keys = driver.execute_query(query, database=database)
    data = []
    for record in records:
        if isinstance(record, neo4j._data.Record):
            for k, v in record.items():
                """
                If both k and v are str type - we have terminal values 
                We check if there is dot in key, split key on dot and take the right size
                For the value:
                       if its a string we will directly assign it
                       if not string eg: a node : we will just take v instead and append to the df
                """
                if isinstance(v, str):                    
                    key = k.split('.')[-1] if '.' in k else k
                    data.append({key: v})
                elif isinstance(v, neo4j.graph.Node):
                    data.append(v)
                else:
                    print("Unknown type", type(v))
    df = pd.DataFrame.from_records(data)
    return df

# %%
# testing
_q = "MATCH (p:Person)-[d:DIRECTED]->(m:Movie) RETURN p.name AS director, m.title AS movie"
print(to_dataframe(_q, driver=driver, database="neo4j"))
# Out:
#            director                  movie
# 0    Lana Wachowski                    NaN
# 1               NaN             The Matrix
# 2    Andy Wachowski                    NaN
# 3               NaN             The Matrix
# 4    Lana Wachowski                    NaN
# ..              ...                    ...
# 83              NaN   Charlie Wilson's War
# 84  Robert Zemeckis                    NaN
# 85              NaN      The Polar Express
# 86   Penny Marshall                    NaN
# 87              NaN  A League of Their Own
#
# [88 rows x 2 columns]

# %%
_q = "MATCH (n:Movie) RETURN n LIMIT 25"
print(to_dataframe(_q, driver=driver, database="neo4j"))
# Out:
# [<Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:0' labels=frozenset({'Movie'}) properties={'tagline': 'Welcome to the Real World', 'title': 'The Matrix', 'released': 1999}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:9' labels=frozenset({'Movie'}) properties={'tagline': 'Free your mind', 'title': 'The Matrix Reloaded', 'released': 2003}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:10' labels=frozenset({'Movie'}) properties={'tagline': 'Everything that has a beginning has an end', 'title': 'The Matrix Revolutions', 'released': 2003}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:11' labels=frozenset({'Movie'}) properties={'tagline': 'Evil has its winning ways', 'title': "The Devil's Advocate", 'released': 1997}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:15' labels=frozenset({'Movie'}) properties={'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'title': 'A Few Good Men', 'released': 1992}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:29' labels=frozenset({'Movie'}) properties={'tagline': 'I feel the need, the need for speed.', 'title': 'Top Gun', 'released': 1986}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:37' labels=frozenset({'Movie'}) properties={'tagline': 'The rest of his life begins now.', 'title': 'Jerry Maguire', 'released': 2000}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:46' labels=frozenset({'Movie'}) properties={'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'title': 'Stand By Me', 'released': 1986}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:52' labels=frozenset({'Movie'}) properties={'tagline': 'A comedy from the heart that goes for the throat.', 'title': 'As Good as It Gets', 'released': 1997}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:56' labels=frozenset({'Movie'}) properties={'tagline': 'After life there is more. The end is just the beginning.', 'title': 'What Dreams May Come', 'released': 1998}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:62' labels=frozenset({'Movie'}) properties={'tagline': 'First loves last. Forever.', 'title': 'Snow Falling on Cedars', 'released': 1999}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:67' labels=frozenset({'Movie'}) properties={'tagline': 'At odds in life... in love on-line.', 'title': "You've Got Mail", 'released': 1998}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:73' labels=frozenset({'Movie'}) properties={'tagline': 'What if someone you never met, someone you never saw, someone you never knew was the only someone for you?', 'title': 'Sleepless in Seattle', 'released': 1993}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:78' labels=frozenset({'Movie'}) properties={'tagline': 'A story of love, lava and burning desire.', 'title': 'Joe Versus the Volcano', 'released': 1990}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:81' labels=frozenset({'Movie'}) properties={'tagline': 'At odds in life... in love on-line.', 'title': 'When Harry Met Sally', 'released': 1998}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:85' labels=frozenset({'Movie'}) properties={'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'title': 'That Thing You Do', 'released': 1996}>>, <Record n=<Node element_id='4:8e34a30c-ce5c-42f4-90db-6003682305d4:87' labels=frozenset({'Movie'}) properties={'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'title': 'The Replacements', 'released': 2000}>>, <Record n=<Node element_ ...
#     released                                            tagline  \
# 0       1999                          Welcome to the Real World
# 1       2003                                     Free your mind
# 2       2003         Everything that has a beginning has an end
# 3       1997                          Evil has its winning ways
# 4       1992  In the heart of the nation's capital, in a cou...
# 5       1986               I feel the need, the need for speed.
# 6       2000                   The rest of his life begins now.
# 7       1986  For some, it's the last real taste of innocenc...
# 8       1997  A comedy from the heart that goes for the throat.
# 9       1998  After life there is more. The end is just the ...
# 10      1999                         First loves last. Forever.
# 11      1998                At odds in life... in love on-line.
# 12      1993  What if someone you never met, someone you nev...
# 13      1990          A story of love, lava and burning desire.
# 14      1998                At odds in life... in love on-line.
# 15      1996  In every life there comes a time when that thi...
# 16      2000  Pain heals, Chicks dig scars... Glory lasts fo...
# 17      2006  Based on the extraordinary true story of one m...
# 18      1996                                    Come as you are
# 19      1992              It's a hell of a thing, killing a man
# 20      1995  The hottest data on earth. In the coolest head...
# 21      2012                            Everything is connected
# 22      2006                                    Break The Codes
# 23      2006                                  Freedom! Forever!
# 24      2008                                Speed has no limits
#
#                      title
# 0               The Matrix
# 1      The Matrix Reloaded
# 2   The Matrix Revolutions
# 3     The Devil's Advocate
# 4           A Few Good Men
# 5                  Top Gun
# 6            Jerry Maguire
# 7              Stand By Me
# 8       As Good as It Gets
# 9     What Dreams May Come
# 10  Snow Falling on Cedars
# 11         You've Got Mail
# 12    Sleepless in Seattle
# 13  Joe Versus the Volcano
# 14    When Harry Met Sally
# 15       That Thing You Do
# 16        The Replacements
# 17              RescueDawn
# 18            The Birdcage
# 19              Unforgiven
# 20         Johnny Mnemonic
# 21             Cloud Atlas
# 22       The Da Vinci Code
# 23          V for Vendetta
# 24             Speed Racer

# %%
query = "MATCH (m:Movie {title: 'Matrix'})<-[:ACTED_IN]-(a:Actor) RETURN a.name"
display(to_dataframe(query, driver, "neo4j"))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
with driver.session(database="neo4j") as session:
    response = session.run("MATCH (n:Movie) RETURN n LIMIT 25")
    for res in response:
        for _,value in res.items():
           for k,v in value.items():
               print(k, v)

# %%
import json

# TODO: this seems like the data on the table vs schema of the graph
with driver.session(database="neo4j") as session:
    response = session.run("CALL apoc.meta.schema()")
    for res in response:
       for val in  res.values():
           print(json.dumps(val, ensure_ascii=False, indent=4))
# Out:
# {
#     "Movie": {
#         "relationships": {
#             "ACTED_IN": {
#                 "count": 180,
#                 "properties": {
#                     "roles": {
#                         "array": true,
#                         "indexed": false,
#                         "existence": false,
#                         "type": "LIST"
#                     }
#                 },
#                 "direction": "in",
#                 "labels": [
#                     "Person",
#                     "Actor"
#                 ]
#             },
#             "REVIEWED": {
#                 "count": 8,
#                 "properties": {
#                     "summary": {
#                         "array": false,
#                         "indexed": false,
#                         "existence": false,
#                         "type": "STRING"
#                     },
#                     "rating": {
#                         "array": false,
#                         "indexed": false,
#                         "existence": false,
#                         "type": "INTEGER"
#                     }
#                 },
#                 "direction": "in",
#                 "labels": [
#                     "Person"
#                 ]
#             },
#             "WROTE": {
#                 "count": 9,
#                 "properties": {},
#                 "direction": "in",
#                 "labels": [
#                     "Person"
#                 ]
#             },
#             "PRODUCED": {
#                 "count": 14,
#                 "properties": {},
#                 "direction": "in",
#                 "labels": [
#                     "Person"
#                 ]
#             },
#             "DIRECTED": {
#                 "count": 44,
#                 "properties": {},
#                 "direction": "in",
#                 "labels": [
#                     "Person"
#                 ]
#             }
#         },
#         "count": 41,
#         "type": "node",
#         "properties": {
#             "name": {
#                 "indexed": false,
#                 "unique": false,
#                 "existence": false,
#                 "type": "STRING"
#             },
#             "tagline": {
#                 "indexed": false,
#                 "unique": false,
#                 "existence": false,
#                 "type": "STRING"
#             },
#             "title": {
#                 "indexed": false,
#                 "unique": false,
#                 "existence": false,
#                 "type": "STRING"
#             },
#             "released": {
#                 "indexed": false,
#                 "unique": false,
#                 "existence": false,
#                 "type": "INTEGER"
#             }
#         },
#         "labels": []
#     },
#     "ACTED_IN": {
#         "count": 184,
#         "type": "relationship",
#         "properties": {
#             "roles": {
#                 "array": true,
#                 "indexed": false,
#                 "existence": false,
#                 "type": "LIST"
#             }
#         }
#     },
#     "REVIEWED": {
#         "count": 8,
#         "type": "relationship",
#         "properties": {
#             "summary": {
#                 "array": false,
#                 "indexed": false,
#                 "existence": false,
#                 "type": "STRING"
#             },
#             "rating": {
#                 "array": false,
#                 "indexed": false,
#                 "existence": false,
#                 "type": "INTEGER"
#             }
#         }
#     },
#     "PRODUCED": {
#         "count": 14,
#         "type": "relationship",
#         "properties": {}
#     },
#     "WROTE": {
#         "count": 9,
#         "type": "relationship",
#         "properties": {}
#     },
#     "Actor": {
#         "relationships": {
#             "ACTED_IN": {
#                 "count": 0,
#                 "properties": {
#                     "roles": {
#                         "array": true,
#                         "indexed": false,
#                         "existence": false,
#                         "type": "LIST"
#                     }
#                 },
#                 "direction": "out",
#                 "labels": [
#                     "Movie"
#                 ]
#             }
#         },
#         "count": 4,
#         "type": "node",
#         "properties": {
#             "name": {
#                 "indexed": false,
#                 "unique": false,
#                 "existence": false,
#                 "type": "STRING"
#             }
#         },
#         "labels": []
#     },
#     "FOLLOWS": {
#         "count": 3,
#         "type": "relationship",
#         "properties": {}
#     },
#     "DIRECTED": {
#         "count": 44,
#         "type": "relationship",
#         "properties": {}
#     },
#     "Person": {
#         "relationships": {
#             "ACTED_IN": {
#                 "count": 0,
#                 "properties": {
#                     "roles": {
#                         "array": true,
#                         "indexed": false,
#                         "existence": false,
#                         "type": "LIST"
#                     }
#                 },
#                 "direction": "out",
#                 "labels": [
#                     "Movie"
#                 ]
#             },
#             "REVIEWED": {
#                 "count": 0,
#                 "properties": {
#                     "summary": {
#                         "array": false,
#                         "indexed": false,
#                         "existence": false,
#                         "type": "STRING"
#                     },
#                     "rating": {
#                         "array": false,
#                         "indexed": false,
#                         "existence": false,
#                         "type": "INTEGER"
#                     }
#                 },
#                 "direction": "out",
#                 "labels": [
#                     "Movie"
#                 ]
#             },
#             "WROTE": {
#                 "count": 0,
#                 "properties": {},
#                 "direction": "out",
#                 "labels": [
#                     "Movie"
#                 ]
#             },
#             "PRODUCED": {
#                 "count": 0,
#                 "properties": {},
#                 "direction": "out",
#                 "labels": [
#                     "Movie"
#                 ]
#             },
#             "FOLLOWS": {
#                 "count": 1,
#                 "properties": {},
#                 "direction": "out",
#                 "labels": [
#                     "Person",
#                     "Person"
#                 ]
#             },
#             "DIRECTED": {
#                 "count": 0,
#                 "properties": {},
#                 "direction": "out",
#                 "labels": [
#                     "Movie"
#                 ]
#             }
#         },
#         "count": 139,
#         "type": "node",
#         "properties": {
#             "born": {
#                 "indexed": false,
#                 "unique": false,
#                 "existence": false,
#                 "type": "INTEGER"
#             },
#             "name": {
#                 "indexed": false,
#                 "unique": false,
#                 "existence": false,
#                 "type": "STRING"
#             }
#         },
#         "labels": []
#     }
# }

# %%
def get_schema(driver) -> str:
    with driver.session(database="neo4j") as session:
        response = session.run("CALL db.schema.visualization()")
        
        nodes = []
        relationships = []

        for res in response:
            for val in res.values():
                for comp in val: # here val is either array of node or relationship
                    #print(type(comp))                
                    if isinstance(comp, neo4j.graph.Node):
                        nodes.append(list(comp.labels)[0])
                    else:
                        relationships.append(("(:{src})-[{rel}]->(:{dst})".format(src=list(comp.start_node.labels)[0], rel=comp.type, dst=list(comp.end_node.labels)[0])))
        node_str = "\n".join(nodes)
        relation_str = "\n".join(relationships)

        return "\n".join(["Nodes:\n", node_str, "\nRelations:\n", relation_str])

# %%
schema =  get_schema(driver)

# %% [markdown]
# ### Generate Cypher Query using Neo4J

# %%
def ask_claude(query, schema):
    prompt = f""" Here is the schema for a database
    {schema}

    Given this schema, can you output a Cypher to answer the following questions? Only output the cypher query and nothing else.

    Question:  {query}
    """
    
    response = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2048,
        messages = [
            {'role': 'user', 'content': prompt}
        ]
    )

    return response.content[0].text

# %%
res = ask_claude("Get all movies that start with T", schema)

print(res)
# Out:
# MATCH (m:Movie)
# WHERE m.title STARTS WITH 'T'
# RETURN m

# %%
res = ask_claude("Get the cast of the movie the matrix", schema)

print(res)
# Out:
# MATCH (m:Movie {title: 'The Matrix'})<-[:ACTED_IN]-(a:Actor)
# RETURN m.title AS movie, collect(a.name) AS cast

# %%
def nl_to_df(query, schema=schema, driver=driver, database="neo4j", verbose=False) -> pd.DataFrame:
    """
    Given a query in natural language. Convert it into a dataframe
    """
    res = ask_claude(query, schema) # this return cypher query
    if verbose:
        print(res)
    if res:
        df = to_dataframe(res, driver, database) # this converts cypher response to dataframe
        return df
    else:
        return pd.DataFrame.empty()

# %%
display(nl_to_df("Show me 10 movies"))
# Out:
#    released                                            tagline  \
# 0      1999                          Welcome to the Real World
# 1      2003                                     Free your mind
# 2      2003         Everything that has a beginning has an end
# 3      1997                          Evil has its winning ways
# 4      1992  In the heart of the nation's capital, in a cou...
# 5      1986               I feel the need, the need for speed.
# 6      2000                   The rest of his life begins now.
# 7      1986  For some, it's the last real taste of innocenc...
# 8      1997  A comedy from the heart that goes for the throat.
# 9      1998  After life there is more. The end is just the ...
#
#                     title
# 0              The Matrix
# 1     The Matrix Reloaded
# 2  The Matrix Revolutions
# 3    The Devil's Advocate
# 4          A Few Good Men
# 5                 Top Gun
# 6           Jerry Maguire
# 7             Stand By Me
# 8      As Good as It Gets
# 9    What Dreams May Come

# %%
display(nl_to_df("Show me 10 movies with their title only with no repeats"))
# Out:
#                     title
# 0              The Matrix
# 1     The Matrix Reloaded
# 2  The Matrix Revolutions
# 3    The Devil's Advocate
# 4          A Few Good Men
# 5                 Top Gun
# 6           Jerry Maguire
# 7             Stand By Me
# 8      As Good as It Gets
# 9    What Dreams May Come

# %%
display(nl_to_df("Who are the cast of A Few Good Men?",  verbose=True))
# Out:
# MATCH (m:Movie {title: "A Few Good Men"})<-[:ACTED_IN]-(p:Person)
# RETURN p.name
#                  name
# 0      James Marshall
# 1        Kevin Pollak
# 2          J.T. Walsh
# 3        Aaron Sorkin
# 4    Cuba Gooding Jr.
# 5   Christopher Guest
# 6           Noah Wyle
# 7   Kiefer Sutherland
# 8         Kevin Bacon
# 9          Demi Moore
# 10     Jack Nicholson
# 11         Tom Cruise

# %%
display(nl_to_df("Movies by Tom Hanks",  verbose=True))
# Out:
# MATCH (tom:Person {name: 'Tom Hanks'})-[:ACTED_IN]->(movie:Movie)
# RETURN movie
#     released                                            tagline  \
# 0       1998                At odds in life... in love on-line.
# 1       1995                        Houston, we have a problem.
# 2       1990          A story of love, lava and burning desire.
# 3       1996  In every life there comes a time when that thi...
# 4       2012                            Everything is connected
# 5       2006                                    Break The Codes
# 6       1993  What if someone you never met, someone you nev...
# 7       1992  Once in a lifetime you get a chance to do some...
# 8       1999                   Walk a mile you'll never forget.
# 9       2007  A stiff drink. A little mascara. A lot of nerv...
# 10      2000      At the edge of the world, his journey begins.
# 11      2004                       This Holiday Season… Believe
#
#                      title
# 0          You've Got Mail
# 1                Apollo 13
# 2   Joe Versus the Volcano
# 3        That Thing You Do
# 4              Cloud Atlas
# 5        The Da Vinci Code
# 6     Sleepless in Seattle
# 7    A League of Their Own
# 8           The Green Mile
# 9     Charlie Wilson's War
# 10               Cast Away
# 11       The Polar Express

# %%
display(nl_to_df("Show me movies by Tom Hanks released after 2000",  verbose=True))
# Out:
# MATCH (p:Person {name: 'Tom Hanks'})-[:ACTED_IN]->(m:Movie)
# WHERE m.released > 2000
# RETURN m
#    released                                            tagline  \
# 0      2012                            Everything is connected
# 1      2006                                    Break The Codes
# 2      2007  A stiff drink. A little mascara. A lot of nerv...
# 3      2004                       This Holiday Season… Believe
#
#                   title
# 0           Cloud Atlas
# 1     The Da Vinci Code
# 2  Charlie Wilson's War
# 3     The Polar Express

# %%
display(nl_to_df("Show movies by Tom Cruise and Tom Hanks",  verbose=True))
# Out:
# MATCH (a:Actor)-[:ACTED_IN]->(m:Movie)
# WHERE a.name IN ['Tom Cruise', 'Tom Hanks']
# RETURN m
#       name
# 0  Top Gun

# %%
display(nl_to_df("Who is the director of top gun?"))
# Out:
#          name
# 0  Tony Scott

# %%
display(nl_to_df("Who are some of the directors of Tom Cruise", verbose=True))
# Out:
# MATCH (tom:Person {name: "Tom Cruise"})-[:ACTED_IN]->(m:Movie)<-[:DIRECTED]-(director:Person)
# RETURN DISTINCT director.name
#             name
# 0  Cameron Crowe
# 1     Tony Scott
# 2     Rob Reiner
